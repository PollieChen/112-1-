# %%
import numpy as np
import pandas as pd
import csv
import matplotlib.pyplot as plt
import seaborn as sns

# %%
#讀取csv文件
df = pd.read_csv('CPICH.csv')
df.head()
# Out:
#    DATE  TAIWAN    US  JAPAN  GERMANY  FRANCE    UK  ITALY  SOUTH KOREA  \
# 0  2000    1.25  3.38  -0.68     1.44    1.68  1.18   2.54         2.26
# 1  2001    0.00  2.83  -0.74     1.98    1.63  1.53   2.79         4.07
# 2  2002   -0.20  1.59  -0.92     1.42    1.92  1.52   2.47         2.76
# 3  2003   -0.28  2.27  -0.26     1.03    2.10  1.38   2.67         3.51
# 4  2004    1.61  2.68  -0.01     1.67    2.14  1.39   2.21         3.59
#
#    SINGAPORE    HK  CHINA
# 0       1.36 -3.69   0.35
# 1       1.00 -1.66   0.72
# 2      -0.39 -2.98  -0.73
# 3       0.51 -2.67   1.13
# 4       1.66 -0.27   3.82

# %%
trace = sns.scatterplot(
    df = df,
    x = 'DATE',
    y = 'US')
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[61], line 1
# ----> 1 trace = sns.scatterplot(
#       2     df = df,
#       3     x = 'DATE',
#       4     y = 'US')
#
# File C:\ProgramData\anaconda3\Lib\site-packages\seaborn\relational.py:742, in scatterplot(data, x, y, hue, size, style, palette, hue_order, hue_norm, sizes, size_order, size_norm, markers, style_order, legend, ax, **kwargs)
#     732 def scatterplot(
#     733     data=None, *,
#     734     x=None, y=None, hue=None, size=None, style=None,
#    (...)
#     738     **kwargs
#     739 ):
#     741     variables = _ScatterPlotter.get_semantics(locals())
# --> 742     p = _ScatterPlotter(data=data, variables=variables, legend=legend)
#     744     p.map_hue(palette=palette, order=hue_order, norm=hue_norm)
#     745     p.map_size(sizes=sizes, order=size_order, norm=size_norm)
#
# ...

# %%
#讀取csv文件
df = pd.read_csv('RU.csv')
df.head()
# Out:
#    DATE  TAIWAN    US  JAPAN  GERMANY  FRANCE    UK  ITALY  SOUTH KOREA  \
# 0  2000    2.99  3.99   4.75     7.92   10.22  5.37  10.05         4.07
# 1  2001    4.57  4.73   5.02     7.77    8.61  5.00   9.01         3.71
# 2  2002    5.17  5.79   5.39     8.48    8.70  5.13   8.48         3.05
# 3  2003    4.99  5.99   5.25     9.78    8.51  4.95   8.43         3.35
# 4  2004    4.44  5.53   4.74    10.73    8.90  4.70   8.05         3.42
#
#    SINGAPORE    HK  CHINA
# 0       3.70  5.11    3.1
# 1       3.70  4.93    3.6
# 2       4.50  7.23    4.0
# 3       5.23  7.93    4.3
# 4       4.43  6.88    4.2

# %%
trace = sns.scatterplot(
    df = pd.DataFrame({
    'x': [1, 2, 3, 4, 5],
    'y': [2, 3, 5, 7, 11]
    }))
   
# 显示图表
plt.show()

# %%
#讀取csv文件
df = pd.read_csv('RX.csv')
df.head()
# Out:
#    DATE    NTD  匯率 - 美國 ( 1 美元所能兌換之特別提款權)     JPY  EURO  EURO.1   GBP  EURO.2  \
# 0  2000  32.99                       0.77  114.90  1.07    1.07  0.67    1.07
# 1  2001  35.00                       0.80  131.80  1.13    1.13  0.69    1.13
# 2  2002  34.75                       0.74  119.90  0.95    0.95  0.62    0.95
# 3  2003  33.98                       0.67  107.10  0.79    0.79  0.56    0.79
# 4  2004  31.92                       0.64  104.12  0.73    0.73  0.52    0.73
#
#       KRW   SGD   HKD   CNY
# 0  1259.7  1.73  7.80  8.28
# 1  1326.1  1.85  7.80  8.28
# 2  1200.4  1.74  7.80  8.28
# 3  1197.8  1.70  7.76  8.28
# 4  1043.8  1.63  7.77  8.28

# %%
df.plot(x = 'DATE', y = ['TAIWAN','US','JAPAN','GERMANY','FRANCE', 'UK', 'HK','CHINA'])


plt.show()
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# Cell In[32], line 1
# ----> 1 df.plot(x = 'DATE', y = ['TAIWAN','US','JAPAN','GERMANY','FRANCE', 'UK', 'HK','CHINA'])
#       4 plt.show()
#
# File C:\ProgramData\anaconda3\Lib\site-packages\pandas\plotting\_core.py:986, in PlotAccessor.__call__(self, *args, **kwargs)
#     983             pass
#     985 # don't overwrite
# --> 986 data = data[y].copy()
#     988 if isinstance(data, ABCSeries):
#     989     label_name = label_kw or y
#
# File C:\ProgramData\anaconda3\Lib\site-packages\pandas\core\frame.py:3813, in DataFrame.__getitem__(self, key)
#    3811     if is_iterator(key):
#    3812         key = list(key)
# -> 3813     indexer = self.columns._get_indexer_strict(key, "columns")[1]
#    3815 # take() does not accept boolean indexers
#    3816 if getattr(indexer, "dtype", None) == bool:
#
# ...
